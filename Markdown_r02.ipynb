# %% [markdown]
# <a href="https://colab.research.google.com/github/yba-arch/demo-repo/blob/main/Markdown_r02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Title
# ## Major Heading
# ### Subheading
# #### for 4th level subheading
#
# Bold text: __String__ not bold **String**
# Italic : _string_ or *string*
#
# #### __Mathematical Symbols__
# $ Mathematical symbols $ RESOLVE<<I don't know whats going on here>>
#
# $$ power(e, (i*pi)) + 1 = 0 $$
#
# #### monospace font
# `string`
# You can use the monospace font for file paths, file names, message text that users see, or text that users enter.
#
# #### line break
# force a line break
# <br>
#
# #### Indenting
#
# > Indent
# not indented
#
# #### Bullets
#
# - item1
# - item2
#
# * item
# * item
#
#     * sub bullet
#
# #### Numbered List
#
# 1. item
# 1. item
# 1. item
#
# #### Graphics
#
# You can attach image files directly to a notebook in Markdown cells by dragging and dropping it into the cell.
# To add images to other cell types, use graphics that are hosted on the web with this code, substituting url/name with the full URL and name of the image:
#
# #### Geometric shapes
#
# https://www.w3schools.com/charsets/ref_utf_geometric.asp
#
# #### Horizontal lines
#
# ***
#
# #### Internal links
#
# [Section title](#section-title)
#
# [Shortcuts](New-Section) << RESOLVE / Not working
#
# Test links in colab
# here is a link
#
# [shortcut test by paste](https://colab.research.google.com/drive/1tuuoXA6cmI4RbDeADRJQeH0-X4Y6EthN#scrollTo=z9e-jv_z_ehw&line=5&uniqifier=1)
#
# #### External links
#
# __[link text](http://url)__

# %% [markdown]
# ## Shortcuts
#
# **View markdown for Table formatting
#
# | Function| Keyboard Shortcut | Menu Tools |
# | :-: | :-: | :-: |
# |Cmd+Shift+ P | Brings up Command Palette | Help > Keyboard Shortcuts / H in command mode
# | Esc | Will take you into command mode where you can navigate around your notebook with arrow keys. |
# | |**While in command mode** |
# | Create new cell	 | Esc + a (above) | Insert→ cell above Insert
# | Create new cell  | Esc + b (below)  |   Insert → cell below
# | Save notebook  |  Esc + S  |  File → Save and Checkpoint
# | M or Y | Toggle between Markdown and  code |
# | D+D (twice) | delete current cell |
# | Enter will exit command mode and back into edit mode for the given cell
# | Run Cell  | Ctrl + enter	 | Cell → Run Cell
# | Interrupt Kernel	|  Esc + i i	| Kernel → Interrupt
# | Restart Kernel	|  Esc + 0 0	| Kernel → Restart
# | Find and replace on your code but not the outputs	 | Esc + f	| N/A
# | When placed before a function Information about a function from its documentation	| ? |

# %% [markdown]
# ## Plotting
#
#
# * matplotlib (the de-facto standard), activated with %matplotlib inline – Here’s a Dataquest Matplotlib Tutorial.
#
# * %matplotlib notebook provides interactivity but can be a little slow, since rendering is done server-side.
# * Seaborn is built over Matplotlib and makes building more attractive plots easier. Just by importing Seaborn, your matplotlib plots are made ‘prettier’ without any code modification.
# * mpld3 provides alternative renderer (using d3) for matplotlib code. Quite nice, though incomplete.
# * bokeh is a better option for building interactive plots.
# * plot.ly can generate nice plots – this used to be a paid service only but was recently open sourced.
# * Altair is a relatively new declarative visualization library for Python. It’s easy to use and makes great looking plots, however the ability to customize those plots is not nearly as powerful as in Matplotlib.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## More tricks & Shortcuts
#
# https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/

# %% [markdown]
# *italicized text*# New Section

# %% [markdown]
# # New Section
#
# ## this text was added in Google colab
#
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# # Math
#
# The Jupyter Notebook uses MathJax to render LaTeX inside HTML / Markdown. Just put your LaTeX math inside $ $. Or enter in display math mode by writing between$$ $$.
#
#
# ## Important Notes:
# To add little spacing in math mode use \,
# To add a new line when in math mode use \\
# To display fraction use \frac{arg 1}{arg 2}
# For power (superscripts text) use ^{}
# For indices (subscripts) use _{}
# For roots use \sqrt[n]{arg}
# The [n]is optional.
# \\
# \\
# \\
#
# $$
# \frac{arg 1}{arg 2} \\
# x^2\\
# e^{i\pi}\\
# A_i\\
# B_{ij}\\
# \sqrt[n]{arg}
# $$
#
#
# Given : $\pi = 3.14$ , $\alpha = \frac{3\pi}{4}\, rad$
# $$
# \omega = 2\pi f \\
# f = \frac{c}{\lambda}\\
# \lambda_0=\theta^2+\delta\\
# \Delta\lambda = \frac{1}{\lambda^2}
# $$
#
# ##Limits
# Limit at plus infinity	: $$\lim_{x \to +\infty} f(x)$$
# Limit at minus infinity	: $$\lim_{x \to -\infty} f(x)$$
# Limit at $\alpha$  : $$\lim_{x \to \alpha} f(x)$$
#
# Max : $$\max_{x \in [a,b]}f(x)$$
# Min : $$\min_{x \in [\alpha,\beta]}f(x)$$
# Sup : $$\sup_{x \in \mathbb{R}}f(x)$$
# Inf : $$\inf_{x > s}f(x)$$
#
# ##Sums
#
# Sum from 0 to +inf:
#
# $$\sum_{j=0}^{+\infty} A_{j}$$
#
# Double sum:
# $$\sum^k_{i=1}\sum^{l+1}_{j=1}\,A_i A_j$$
#
#
# Taylor expansion of $e^x$:
# $$ e^x  = \sum_{k=0}^{n}\, \frac{x^k}{k!} + o(x^n) $$
#
# ##Product
#
# Product:
# $$\prod_{j=1}^k A_{\alpha_j}$$
# Double product:
# $$\prod^k_{i=1}\prod^l_{j=1}\,A_i A_j$$
#
# ##Integrals
#
# Simple integral:
# $$\int_{a}^b f(x)dx$$
#
# Double integral:
# $$\int_{a}^b\int_{c}^d f(x,y)\,dxdy$$
#
# Triple integral:
# $$\iiint$$
#
# Quadruple integral:
# $$\iiiint$$
#
# Multiple integral :
# $$\idotsint$$
#
# Contour integral:
# $$\oint$$
#
# ##Matrix
#
#
# Plain:
#
# \begin{matrix}
# 1 & 2 & 3\\
# a & b & c
# \end{matrix}
#
# Round brackets:
# \begin{pmatrix}
# 1 & 2 & 3\\
# a & b & c
# \end{pmatrix}
#
# Curly brackets:
# \begin{Bmatrix}
# 1 & 2 & 3\\
# a & b & c
# \end{Bmatrix}
#
# Pipes:
# \begin{vmatrix}
# 1 & 2 & 3\\
# a & b & c
# \end{vmatrix}
#
# Double pipes
# \begin{Vmatrix}
# 1 & 2 & 3\\
# a & b & c
# \end{Vmatrix}
#
#
#
#
#
#
# Additional Resources
#
# Resources:
#
# https://www.datasciencecentral.com/profiles/blogs/all-about-using-jupyter-notebooks-and-google-colab
# https://oeis.org/wiki/List_of_LaTeX_mathematical_symbols
# https://jupyter.org/
# https://en.wikipedia.org/wiki/Project_Jupyter
# https://en.wikipedia.org/wiki/Markdown
# http://tug.ctan.org/info/undergradmath/
# https://openclassrooms.com/en/courses/1304236-redigez-en-markdown
#
# https://latexeditor.lagrida.com/
